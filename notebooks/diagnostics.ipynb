# %%
import sys
if 'src.data.preprocess' in sys.modules:
    del sys.modules['src.data.preprocess']

try:
    import src.data.preprocess as pre
    print('module loaded:', pre.__file__)
    print('load_and_clean_data exists:', hasattr(pre, 'load_and_clean_data'))
except Exception as e:
    import traceback
    traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\elisha\AppData\Local\Temp\ipykernel_9120\481750377.py", line 6, in <module>
#     import src.data.preprocess as pre
# ModuleNotFoundError: No module named 'src'
